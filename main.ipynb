# %%
# imports
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import glob

# %%
# setup data 
image_list = []

# filename/shape/type/label
for filepath in glob.glob('images/*/*/*.png', recursive=True):
     filename = filepath.split("/")[-1]
     sign_shape = filepath.split("/")[-1]
     sign_type = filepath.split("/")[-1]
     print(sign_type)
          
     image_list.append(filename,sign_shape,sign_type)
     
data = pd.DataFrame(data=image_list, columns=['sign_shape', 'sign_type'])
# Out:
# images\diamond\rightofway\00032_00000.png
# images\diamond\rightofway\00032_00001.png
# images\diamond\rightofway\00032_00002.png
# images\diamond\rightofway\00037_00000.png
# images\diamond\rightofway\00037_00001.png
# images\diamond\rightofway\00037_00002.png
# images\diamond\rightofway\00039_00000.png
# images\diamond\rightofway\00039_00001.png
# images\diamond\rightofway\00039_00002.png
# images\diamond\rightofway\00042_00000.png
# images\diamond\rightofway\00042_00001.png
# images\diamond\rightofway\00042_00002.png
# images\diamond\rightofway\00044_00000.png
# images\diamond\rightofway\00044_00001.png
# images\diamond\rightofway\00044_00002.png
# images\diamond\rightofway\00045_00000.png
# images\diamond\rightofway\00045_00001.png
# images\diamond\rightofway\00045_00002.png
# images\diamond\rightofway\00046_00000.png
# images\diamond\rightofway\00046_00001.png
# images\diamond\rightofway\00050_00000.png
# images\diamond\rightofway\00050_00001.png
# ...

# %% [markdown]
# Dataframes for training and validation

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Input
from tensorflow.keras import regularizers, optimizers

input_ = Input(shape=(28,28,3))
